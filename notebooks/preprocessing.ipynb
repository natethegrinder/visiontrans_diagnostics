# %% [markdown]
# # Download Dataset
# ```shell
# python src/download_nih_dataset.py \
#   --dataset "https://www.kaggle.com/datasets/nih-chest-xrays/data/download?datasetVersionNumber=3" \
#   --output-dir data/raw \
#   --annotations-dir data/annotations
# ```
# We only run this one time.
